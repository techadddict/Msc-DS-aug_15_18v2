# %%
from tkinter import * 

class CreditScorecard(Frame): 
 def __init__(self,master= None): 
    Frame.__init__(self,master, width =2000, height =2000)
    self.pack()

    #scorecard title
    Label(self, text ='Home Loans Credit scorecard').grid(row=0, column=1)  

    #name of client 
    Label(self, text ='Client name ').grid(row=1,column=1)

    self.word_2 = StringVar()
    Entry(self, width =10, textvariable =self.word_2).grid(row=1,column=2)

    #
    Label(self, text ='Surname').grid(row=2,column=1)

    self.word_3 = StringVar()
    Entry(self, width =10, textvariable =self.word_3).grid(row=2,column=2)


    # 'DAYS_BIRTH' = age*365
    Label(self, text ='Age',anchor=NW, justify=LEFT).grid(row=3,column=1)

    self.word_4 = StringVar()
    Entry(self, width =10, textvariable =self.word_4).grid(row=3,column=2)

    #   
    Label(self, text ='Gender').grid(row=4,column=1)

    # DROPDOWN MENU

    Gender_var = StringVar(self)
    Gender_var.set("F") # initial value
    OptionMenu(self, Gender_var, "F", "M").grid(row=4, column=2)

    #  
    Label(self, text ='Marital Status').grid(row=5,column=1)

    marital_status_var = StringVar(self)
    marital_status_var.set("Single") # initial value
    OptionMenu(self, marital_status_var, "Single", "Married","Civil marriage", "Separated","Widow").grid(row=5, column=2)


    #  
    Label(self, text ='Home address').grid(row=6,column=1)

    self.word_7 = StringVar()
    Entry(self, width =10, textvariable = self.word_7).grid(row=6,column =2)

    #REG_CITY_NOT_LIVE_CITY
    Label(self, text ='Home address same as contact address').grid(row=7,column=1)

    self.word_8 = StringVar()
    Entry(self, width =10, textvariable = self.word_8).grid(row=7,column =2)    



    #  REGION_RATING_CLIENT'  
    Label(self, text ='Home region rating').grid(row=8,column=1)

    self.word_9 = StringVar()
    Entry(self, width =10, textvariable = self.word_9).grid(row=8,column =2)

    #'REGION_POPULATION_RELATIVE',
    Label(self, text ='Region population relative').grid(row=9,column=1)

    self.word_10 = StringVar()
    Entry(self, width =10, textvariable = self.word_10).grid(row=9,column =2)



    Label(self, text ='Contact number').grid(row=10,column=1)

    self.word_11 = StringVar()
    Entry(self, width =10, textvariable = self.word_11).grid(row=10,column =2)

    #DAYS_LAST_PHONE_CHANGE',
    Label(self, text ='Days since phone change').grid(row=11,column=1)

    self.word_12 = StringVar()
    Entry(self, width =10, textvariable = self.word_12).grid(row=11,column =2) 

    #'OBS_30_CNT_SOCIAL_CIRCLE',
    Label(self, text ='Number of clients with close to 30 DPD (days past due > 25) default in clients home region').grid(row=12,column=1)

    self.word_13 = StringVar()
    Entry(self, width =10, textvariable = self.word_13).grid(row=12,column =2)

    #DEF_30_CNT_SOCIAL_CIRCLE',
    Label(self, text ='Number of clients in customers home region in default on 30 DPD (days past due)').grid(row=13,column=1)

    self.word_14 = StringVar()
    Entry(self, width =10, textvariable = self.word_14).grid(row=13,column =2)

    #
    Label(self, text ='Employment status').grid(row=14,column=1)

    self.word_15 = StringVar()
    Entry(self, width =10, textvariable = self.word_15).grid(row=14,column =2)

    # DAYS_EMPLOYED' = Number of years in current job* 365 OR 5 DAY WEEK
    Label(self, text ='Number of years in current job').grid(row=15,column=1)

    self.word_16 = StringVar()
    Entry(self, width =10, textvariable = self.word_16).grid(row=15,column =2 )

    #categorical_grouped_NAME_EDUCATION_TYPE_Higher education_mean'
    Label(self, text ='Highest education level/type').grid(row=16,column=1)

    #DROP DOWN MENU
    education_var = StringVar(self)
    education_var.set("Lower_Secondary") # initial value
    OptionMenu(self, education_var, "Academic degree", "Higher education","Incomplete higher", "Lower secondary","Secondary").grid(row=16,column=2)


    #AMT_INCOME_TOTAL',
    Label(self, text ='Annual income').grid(row=17,column=1)

    self.word_18 = StringVar()
    Entry(self, width =10, textvariable = self.word_18).grid(row=17,column=2)

    #   categorical_grouped_NAME_INCOME_TYPE_Working_mean'
    Label(self, text ='Income type').grid(row=18,column=1)

    self.word_19 = StringVar()
    Entry(self, width =10, textvariable = self.word_19).grid(row=18,column=2)

    #AMT_CREDIT
    Label(self, text ='Loan amount applied for').grid(row=19,column=1)

    self.word_20 = StringVar()
    Entry(self, width =10, textvariable = self.word_20).grid(row=19,column=2)

    # AMT_ANNUITY',   
    Label(self, text ='Installment amount based on loan applied for').grid(row=20,column=1)

    self.word_21 = StringVar()
    Entry(self, width =10, textvariable = self.word_21).grid(row=20,column=2)

    #  DEBT_TO_INCOME',
    Label(self, text ='Total debt to income ratio').grid(row=21,column=1)

    self.word_22 = StringVar()
    Entry(self, width =10, textvariable = self.word_22).grid(row=21,column=2)

    #   to  be added if chosen 
    Label(self, text ='Total repayment amount to income ratio').grid(row=22,column=1)

    self.word_23 = StringVar()
    Entry(self, width =10, textvariable = self.word_23).grid(row=22,column=2)

    #   
    Label(self, text ='Did client submit all requiredDocuments').grid(row=23,column=1)

    # DROP DOWN MENU
    all_DOCS_var = StringVar(self)
    all_DOCS_var.set("No") # 1 - yes, 0 is no
    OptionMenu(self, all_DOCS_var , "Yes", "No").grid(row=23,column=2)

    # 'FLAG_DOCUMENT_3'  
    Label(self, text ='Did client submit Document 3').grid(row=24,column=1)

    self.word_25 = StringVar()
    Entry(self, width =10, textvariable = self.word_25).grid(row=24,column=2)


    doc3_var = StringVar(self)
    doc3_var .set("No") #  1 - yes, 0 is no
    OptionMenu(self, doc3_var  , "Yes", "No").grid(row=24,column=2)

    #  DAYS_REGISTRATION', 
    Label(self, text ='Days since registration change').grid(row=25,column=1)

    self.word_26 = StringVar()
    Entry(self, width =10, textvariable = self.word_26).grid(row=25,column=2)

    #DAYS_ID_PUBLISH',
    Label(self, text ='Days since ID change').grid(row=26,column=1)

    self.word_27 = StringVar()
    Entry(self, width =10, textvariable = self.word_27).grid(row=26,column=2)


    # HOUR_APPR_PROCESS_START               
    Label(self, text ='Time loan application submitted').grid(row=27,column=1)

    self.word_28 = StringVar()
    Entry(self, width =10, textvariable = self.word_28).grid(row=27,column=2)

    # EXT_SOURCE_2               
    Label(self, text ='Normalized score (must be between 0 and 1) from external data source').grid(row=28,column=1)

    self.word_29 = StringVar()
    Entry(self, width =10, textvariable = self.word_29).grid(row=28,column=2)

if __name__ == "__main__": 

   CreditScorecard().mainloop()

# %% [markdown]
# from tkinter import *
# class CreditScorecard(Frame):
#     def __init__(self,master= None):
#      Frame.__init__(self,master, width =2000, height =2000)
#      self.pack()
#
#      #scorecard title
#      Label(self, text ='Home Loans Credit scorecard').grid(row=0, column=1)
#
#      #name of client
#      Label(self, text ='Client name ').grid(row=1,column=1)
#
#      self.word_2 = StringVar()
#      Entry(self, width =10, textvariable =self.word_2).grid(row=1,column=2)
#
#      #
#      Label(self, text ='Surname').grid(row=2,column=1)
#
#      self.word_3 = StringVar()
#      Entry(self, width =10, textvariable =self.word_3).grid(row=2,column=2)
#
#
#      # 'DAYS_BIRTH' = age*365
#      Label(self, text ='Age',anchor=NW, justify=LEFT).grid(row=3,column=1)
#
#      self.word_4 = StringVar()
#      Entry(self, width =10, textvariable =self.word_4).grid(row=3,column=2)
#
#      #
#      Label(self, text ='Gender').grid(row=4,column=1)
#
#      # DROPDOWN MENU
#
#      Gender_var = StringVar(self)
#      Gender_var.set("F") # initial value
#      OptionMenu(self, Gender_var, "F", "M").grid(row=4, column=2)
#
#       #
#      Label(self, text ='Marital Status').grid(row=5,column=1)
#
#      marital_status_var = StringVar(self)
#      marital_status_var.set("Single") # initial value
#      OptionMenu(self, marital_status_var, "Single", "Married","Civil marriage", "Separated","Widow").grid(row=5, column=2)
#
#
#      #
#      Label(self, text ='Home address').grid(row=6,column=1)
#
#      self.word_7 = StringVar()
#      Entry(self, width =10, textvariable = self.word_7).grid(row=6,column =2)
#
#      #REG_CITY_NOT_LIVE_CITY
#      Label(self, text ='Home address same as contact address').grid(row=7,column=1)
#
#      self.word_8 = StringVar()
#      Entry(self, width =10, textvariable = self.word_8).grid(row=7,column =2)
#
#
#
#      #  REGION_RATING_CLIENT'
#      Label(self, text ='Home region rating').grid(row=8,column=1)
#
#      self.word_9 = StringVar()
#      Entry(self, width =10, textvariable = self.word_9).grid(row=8,column =2)
#
#      #'REGION_POPULATION_RELATIVE',
#      Label(self, text ='Region population relative').grid(row=9,column=1)
#
#      self.word_10 = StringVar()
#      Entry(self, width =10, textvariable = self.word_10).grid(row=9,column =2)
#
#
#
#      Label(self, text ='Contact number').grid(row=10,column=1)
#
#      self.word_11 = StringVar()
#      Entry(self, width =10, textvariable = self.word_11).grid(row=10,column =2)
#
#      #DAYS_LAST_PHONE_CHANGE',
#      Label(self, text ='Days since phone change').grid(row=11,column=1)
#
#      self.word_12 = StringVar()
#      Entry(self, width =10, textvariable = self.word_12).grid(row=11,column =2)
#
#     #'OBS_30_CNT_SOCIAL_CIRCLE',
#      Label(self, text ='Number of clients with close to 30 DPD (days past due > 25) default in clients home region').grid(row=12,column=1)
#
#      self.word_13 = StringVar()
#      Entry(self, width =10, textvariable = self.word_13).grid(row=12,column =2)
#
#      #DEF_30_CNT_SOCIAL_CIRCLE',
#      Label(self, text ='Number of clients in customers home region in default on 30 DPD (days past due)').grid(row=13,column=1)
#
#      self.word_14 = StringVar()
#      Entry(self, width =10, textvariable = self.word_14).grid(row=13,column =2)
#
#      #
#      Label(self, text ='Employment status').grid(row=14,column=1)
#
#      self.word_15 = StringVar()
#      Entry(self, width =10, textvariable = self.word_15).grid(row=14,column =2)
#
#      # DAYS_EMPLOYED' = Number of years in current job* 365 OR 5 DAY WEEK
#      Label(self, text ='Number of years in current job').grid(row=15,column=1)
#
#      self.word_16 = StringVar()
#      Entry(self, width =10, textvariable = self.word_16).grid(row=15,column =2 )
#
#      #categorical_grouped_NAME_EDUCATION_TYPE_Higher education_mean'
#      Label(self, text ='Highest education level/type').grid(row=16,column=1)
#
#      #DROP DOWN MENU
#      education_var = StringVar(self)
#      education_var.set("Lower_Secondary") # initial value
#      OptionMenu(self, education_var, "Academic degree", "Higher education","Incomplete higher", "Lower secondary","Secondary").grid(row=16,column=2)
#
#
#      #AMT_INCOME_TOTAL',
#      Label(self, text ='Annual income').grid(row=17,column=1)
#
#      self.word_18 = StringVar()
#      Entry(self, width =10, textvariable = self.word_18).grid(row=17,column=2)
#
#      #   categorical_grouped_NAME_INCOME_TYPE_Working_mean'
#      Label(self, text ='Income type').grid(row=18,column=1)
#
#      self.word_19 = StringVar()
#      Entry(self, width =10, textvariable = self.word_19).grid(row=18,column=2)
#
#      #AMT_CREDIT
#      Label(self, text ='Loan amount applied for').grid(row=19,column=1)
#
#      self.word_20 = StringVar()
#      Entry(self, width =10, textvariable = self.word_20).grid(row=19,column=2)
#
#     # AMT_ANNUITY',
#      Label(self, text ='Installment amount based on loan applied for').grid(row=20,column=1)
#
#      self.word_21 = StringVar()
#      Entry(self, width =10, textvariable = self.word_21).grid(row=20,column=2)
#
#      #  DEBT_TO_INCOME',
#      Label(self, text ='Total debt to income ratio').grid(row=21,column=1)
#
#      self.word_22 = StringVar()
#      Entry(self, width =10, textvariable = self.word_22).grid(row=21,column=2)
#
#      #   to  be added if chosen
#      Label(self, text ='Total repayment amount to income ratio').grid(row=22,column=1)
#
#      self.word_23 = StringVar()
#      Entry(self, width =10, textvariable = self.word_23).grid(row=22,column=2)
#
#      #
#      Label(self, text ='Did client submit all requiredDocuments').grid(row=23,column=1)
#
#      # DROP DOWN MENU
#      all_DOCS_var = StringVar(self)
#      all_DOCS_var.set("No") # 1 - yes, 0 is no
#      OptionMenu(self, all_DOCS_var , "Yes", "No").grid(row=23,column=2)
#
#      # 'FLAG_DOCUMENT_3'
#      Label(self, text ='Did client submit Document 3').grid(row=24,column=1)
#
#      self.word_25 = StringVar()
#      Entry(self, width =10, textvariable = self.word_25).grid(row=24,column=2)
#
#
#      doc3_var = StringVar(self)
#      doc3_var .set("No") #  1 - yes, 0 is no
#      OptionMenu(self, doc3_var  , "Yes", "No").grid(row=24,column=2)
#
#      #  DAYS_REGISTRATION',
#      Label(self, text ='Days since registration change').grid(row=25,column=1)
#
#      self.word_26 = StringVar()
#      Entry(self, width =10, textvariable = self.word_26).grid(row=25,column=2)
#
#      #DAYS_ID_PUBLISH',
#      Label(self, text ='Days since ID change').grid(row=26,column=1)
#
#      self.word_27 = StringVar()
#      Entry(self, width =10, textvariable = self.word_27).grid(row=26,column=2)
#
#
#       # HOUR_APPR_PROCESS_START
#      Label(self, text ='Time loan application submitted').grid(row=27,column=1)
#
#      self.word_28 = StringVar()
#      Entry(self, width =10, textvariable = self.word_28).grid(row=27,column=2)
#
#      # EXT_SOURCE_2
#      Label(self````````````, text ='Normalized score (must be between 0 and 1) from external data source').grid(row=28,column=1)
#
#      self.word_29 = StringVar()
#      Entry(self, width =10, textvariable = self.word_29).grid(row=28,column=2)
#
#
#
#
# if __name__ ==  "__main__":
#    CreditScorecard().mainloop()
